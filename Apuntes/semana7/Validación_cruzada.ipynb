# %% [markdown]
# # Validación cruzada
#
# La validación cruzada (cross-validation) es una técnica estadística utilizada para evaluar el rendimiento de un modelo de aprendizaje automático y asegurar que los resultados obtenidos no dependan únicamente de una partición específica de los datos.
#
# En lugar de entrenar y evaluar el modelo en una única división entre entrenamiento y prueba, la validación cruzada divide el conjunto de datos en múltiples subconjuntos o folds. El modelo se entrena múltiples veces, cada vez utilizando un fold diferente como conjunto de prueba y el resto como conjunto de entrenamiento. La métrica de evaluación final se obtiene promediando los resultados obtenidos en cada iteración.
#
# Una de las variantes más comunes es la validación cruzada k-fold, donde el conjunto de datos se divide en k partes iguales. Esta técnica permite una estimación más robusta del rendimiento del modelo y ayuda a reducir el riesgo de sobreajuste.

# %% [markdown]
# ![K-fold_cross_validation_EN.svg.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
#  Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargar el archivo
personas = pd.read_csv('//content/drive/MyDrive/Minería de datos UNAB/Clase VII/Taller/salario.csv')
personas.head()
# Out:
#    edad  estudio  ingreso
# 0    27        9        0
# 1    30        9        0
# 2    34        8        0
# 3    26       13        0
# 4    23        4        0

# %%
bosque = RandomForestClassifier()

bosque.fit(personas[["edad", "estudio"]].values,
          personas["ingreso"].values)

print(bosque.score(personas[["edad", "estudio"]].values,
                  personas["ingreso"].values))
# Out:
# 0.97

# %%
print(cross_val_score(bosque,
                     personas[["edad", "estudio"]].values,
                     personas["ingreso"].values,
                     cv=5))


#
# Out:
# [0.75 0.9  0.75 0.7  0.8 ]
